# %% [markdown]
# ### 库导入

# %%
import pandas as pd

# %% [markdown]
# ### 数据加载与预处理

# %%
# 读取原始数据文件
df_raw_buyback = pd.read_excel("./data/raw/股份回购.xlsx", dtype={"SCode": str}, skiprows=[1], nrows=10)
df_raw_dividend = pd.read_excel("./data/raw/分红实施内容.xlsx", dtype={"SCode": str}, skiprows=[1], nrows=10)

print(df_raw_buyback.head())
print(df_raw_dividend.head())
print(df_raw_buyback.info())
print(df_raw_dividend.info())
# Out:
#     SCode     BPAmtDy     SoAmDAD     RepMaNum   RepMiNum RepType RepProc  \
# 0  000002  2015-07-06  2015-09-01   12480299.0   12480299    普通回购    实施完成
# 1  000002  2022-03-31         NaN  136836344.0  109469075    普通回购     实施中
# 2  000004  2021-05-27         NaN    9049599.0    9049599    普通回购    完成实施
# 3  000004  2022-04-30  2022-05-21   23155018.0   23155018    普通回购  股东大会通过
# 4  000004  2023-04-29  2023-05-20     939474.0     939474    普通回购     实施中
#
#          MaxPrc        MinPrc  AvePrc       RepSN       RepAmt     RepSDat  \
# 0  1.000000e+10           NaN   12.83  12480299.0  160148520.0  2015-09-01
# 1  2.500000e+09  2.000000e+09   17.94   3457870.0   61845219.3  2022-03-30
# 2  1.000000e+00  1.000000e+00    0.00   9049599.0          1.0         NaN
# 3  1.000000e+00  1.000000e+00     NaN         NaN          NaN         NaN
# 4  1.000000e+00  1.000000e+00     NaN    467726.0          0.5         NaN
#
#       RepDDat
# 0  2015-12-31
# 1  2022-06-30
# 2         NaN
# ...

# %%
# 查看数据基本信息
